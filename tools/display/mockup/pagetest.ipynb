# %% [markdown]
# ## Page Test
# Test the functionality of pyMDL display.
# * Use with dbAPIsim.py

# %%
#Autoreload display module so I can change it while developing
# %load_ext autoreload
# %autoreload 1 #This specifies that %aimport modules are reloaded
# %aimport pymdl.display

#Import PIL and use matplotlib for display
from PIL import ImageFont
import matplotlib.pyplot as plt
import pymdl.display as display
import numpy as np
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#Define font
cherry = ImageFont.load('fonts/cherry-10-r.pil')

# %% [markdown]
# ### System Display

# %%
#Create a system display
systemdisp = display.system_display()
systemdisp.font = cherry
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# <ipython-input-18-316683e8abcc> in <module>
#       1 #Create a system display
# ----> 2 systemdisp = display.system_display()
#       3 systemdisp.font = cherry
#
# c:\users\clmbn\programming\pymdl\pymdl\display\__init__.py in __init__(self)
#      33         self.dbstatus = 'Not running'
#      34         self.sensors = []
# ---> 35         self.getstatus()
#      36
#      37     def getstatus(self):
#
# c:\users\clmbn\programming\pymdl\pymdl\display\__init__.py in getstatus(self)
#      43         try:
#      44             sock.sendto(cmd.encode('utf-8'),(HOST,PORT))
# ---> 45             response = sock.recv(1024)
#      46         except socket.timeout:
#      47             return
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host

# %%
#Render image
img = systemdisp.renderPage()
npimg = np.asarray(img)
plt.imshow(npimg,cmap='gray')

# %% [markdown]
# ### Data Display

# %%
#Clear image
d.rectangle([(0,0),(128,64)],fill=0)

#Display content
headstr = 'TPH-1   20:05:10'
datastr = ('T:  20.56 C\n'
           'RH: 35%\n'
           'BP: 890 mb\n')

d.text((0,0),headstr,font=libm,fill=255)
d.multiline_text(
        (20,20),
        datastr,
        font=libm,
        fill=255,
        spacing=2)

#Draw a rectangle to indicate more data
d.polygon([(50,110),(50,120),(55,105)],fill=255)

npim = np.asarray(im)
plt.imshow(npim,cmap='gray')

# %% [markdown]
# ### Test data display: default font

# %%
dfnt = ImageFont.load_default()

#Clear image
d.rectangle([(0,0),(128,64)],fill=0)

#Display content
headstr = ' TPH-1   20:05:10'
datastr = ('T:  20.56 C\n'
           'RH: 35%\n'
           'BP: 890 mb\n')

d.text((0,0),headstr,font=dfnt,fill=255)
d.multiline_text(
        (20,20),
        datastr,
        font=dfnt,
        fill=255,
        spacing=2)

#Draw a rectangle to indicate more data
d.polygon([(110,50),(120,50),(115,55)],fill=255)

npim = np.asarray(im)
plt.imshow(npim,cmap='gray')

# %% [markdown]
# #### Test system display

# %%
#Clear image
d.rectangle([(0,0),(128,64)],fill=0)

#Display content
headerstr = ('MDL-700     13:45:22\n'
             'Status\n')
statstr = ('DataBear: Running\n'
           'Battery:  12.35V\n'
           'No problems detected')

d.multiline_text(
        (5,0),
        headerstr,
        font=dfnt,
        fill=255,
        spacing=2)

d.multiline_text(
        (5,25),
        statstr,
        font=dfnt,
        fill=255,
        spacing=2)
d.line([(5,24),(40,24)],width=1,fill=255)

npim = np.asarray(im)
plt.imshow(npim,cmap='gray')
